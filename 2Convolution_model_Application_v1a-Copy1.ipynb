# %% [markdown]
# # Convolutional Neural Networks: Application
#
# Welcome to Course 4's second assignment! In this notebook, you will:
#
# - Implement helper functions that you will use when implementing a TensorFlow model
# - Implement a fully functioning ConvNet using TensorFlow
#
# **After this assignment you will be able to:**
#
# - Build and train a ConvNet in TensorFlow for a classification problem
#
# We assume here that you are already familiar with TensorFlow. If you are not, please refer the *TensorFlow Tutorial* of the third week of Course 2 ("*Improving deep neural networks*").

# %% [markdown]
# ### <font color='darkblue'> Updates to Assignment <font>
#
# #### If you were working on a previous version
# * The current notebook filename is version "1a".
# * You can find your work in the file directory as version "1".
# * To view the file directory, go to the menu "File->Open", and this will open a new tab that shows the file directory.
#
# #### List of Updates
# * `initialize_parameters`: added details about tf.get_variable, `eval`. Clarified test case.
# * Added explanations for the kernel (filter) stride values, max pooling, and flatten functions.
# * Added details about softmax cross entropy with logits.
# * Added instructions for creating the Adam Optimizer.
# * Added explanation of how to evaluate tensors (optimizer and cost).
# * `forward_propagation`: clarified instructions, use "F" to store "flatten" layer.
# * Updated print statements and 'expected output' for easier visual comparisons.
# * Many thanks to Kevin P. Brown (mentor for the deep learning specialization) for his suggestions on the assignments in this course!

# %% [markdown]
# ## 1.0 - TensorFlow model
#
# In the previous assignment, you built helper functions using numpy to understand the mechanics behind convolutional neural networks. Most practical applications of deep learning today are built using programming frameworks, which have many built-in functions you can simply call.
#
# As usual, we will start by loading in the packages.

# %%
import math
import numpy as np 
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow.compat.v1 as tf
#tf.enable_eager_execution()
tf.disable_v2_behavior()
from tensorflow.python.framework import ops
from cnn_utils import *
import cv2
import glob

# %matplotlib inline
np.random.seed(1)

print(tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\Tobyw\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\compat\v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2.0.0-rc2

# %%
AUTOTUNE=tf.data.experimental.AUTOTUNE
import IPython.display as display
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

# %%
import pathlib
data_dir = './data/asl_alphabet_train/asl_alphabet_train'
data_dir = pathlib.Path(data_dir)
#to find out how many images we have to deal with
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 87000

# %%
data_dir_test = './data/asl_alphabet_test/asl_alphabet_test/'
data_dir_test = pathlib.Path(data_dir_test)
#to find out how many images we have to deal with
image_count = len(list(data_dir_test.glob('*.jpg')))
image_count
# Out:
# 29

# %%
X_data = []
files = data_dir.glob('*/*.jpg')
for myFile in files:
    print(myFile)
    image = cv2.imread(str(myFile), cv2.IMREAD_COLOR)
    X_data.append(image/255)

X_data = np.array(X_data)
print('X_data shape:', X_data.shape)
# Out:
# data\asl_alphabet_train\asl_alphabet_train\A\A1.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A10.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A100.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1000.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1001.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1002.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1003.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1004.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1005.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1006.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1007.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1008.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1009.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A101.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1010.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1011.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1012.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1013.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1014.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1015.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1016.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1017.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1018.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1019.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A102.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1020.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1021.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1022.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1023.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1024.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1025.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1026.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1027.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1028.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1029.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A103.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1030.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1031.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1032.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1033.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1034.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1035.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1036.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1037.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1038.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1039.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A104.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1040.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1041.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1042.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1043.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1044.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1045.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1046.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1047.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1048.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1049.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A105.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1050.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1051.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1052.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1053.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1054.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1055.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1056.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1057.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1058.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1059.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A106.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1060.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1061.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1062.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1063.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1064.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1065.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1066.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1067.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1068.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1069.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A107.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1070.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1071.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1072.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1073.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1074.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1075.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1076.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1077.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1078.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1079.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A108.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1080.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1081.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1082.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1083.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1084.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1085.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1086.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1087.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1088.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1089.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A109.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1090.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1091.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1092.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1093.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1094.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1095.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1096.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1097.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1098.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1099.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A11.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A110.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1100.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1101.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1102.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1103.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1104.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1105.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1106.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1107.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1108.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1109.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A111.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1110.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1111.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1112.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1113.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1114.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1115.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1116.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1117.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1118.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1119.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A112.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1120.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1121.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1122.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1123.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1124.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1125.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1126.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1127.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1128.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1129.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A113.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1130.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1131.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1132.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1133.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1134.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1135.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1136.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1137.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1138.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1139.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A114.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1140.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1141.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1142.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1143.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A1144.jpg
# data\asl_alphabet_train\asl_alphabet_train\A\A
jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H328.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H329.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H33.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H330.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H331.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H332.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H333.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H334.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H335.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H336.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H337.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H338.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H339.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H34.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H340.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H341.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H342.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H343.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H344.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H345.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H346.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H347.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H348.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H349.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H35.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H350.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H351.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H352.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H353.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H354.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H355.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H356.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H357.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H358.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H359.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H36.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H360.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H361.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H362.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H363.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H364.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H365.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H366.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H367.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H368.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H369.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H37.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H370.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H371.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H372.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H373.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H374.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H375.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H376.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H377.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H378.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H379.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H38.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H380.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H381.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H382.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H383.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H384.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H385.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H386.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H387.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H388.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H389.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H39.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H390.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H391.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H392.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H393.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H394.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H395.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H396.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H397.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H398.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H399.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H4.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H40.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H400.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H401.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H402.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H403.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H404.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H405.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H406.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H407.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H408.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H409.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H41.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H410.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H411.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H412.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H413.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H414.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H415.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H416.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H417.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H418.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H419.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H42.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H420.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H421.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H422.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H423.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H424.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H425.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H426.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H427.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H428.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H429.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H43.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H430.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H431.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H432.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H433.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H434.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H435.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H436.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H437.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H438.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H439.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H44.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H440.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H441.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H442.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H443.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H444.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H445.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H446.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H447.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H448.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H449.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H45.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H450.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H451.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H452.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H453.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H454.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H455.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H456.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H457.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H458.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H459.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H46.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H460.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H461.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H462.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H463.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H464.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H465.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H466.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H467.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H468.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H469.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H47.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H470.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H471.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H472.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H473.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H474.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H475.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H476.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H477.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H478.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H479.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H48.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H480.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H481.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H482.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H483.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H484.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H485.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H486.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H487.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H488.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H489.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H49.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H490.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H491.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H492.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H493.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H494.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H495.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H496.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H497.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H498.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H499.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H5.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H50.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H500.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H501.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H502.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H503.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H504.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H505.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H506.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H507.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H508.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H509.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H51.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H510.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H511.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H512.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H513.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H514.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H515.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H516.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H517.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H518.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H519.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H52.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H520.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H521.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H522.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H523.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H524.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H525.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H526.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H527.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H528.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H529.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H53.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H530.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H531.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H532.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H533.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H534.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H535.jpg
# data\asl_alphabet_train\asl_alphabet_train\H\H536.jpg

# %%
X_data_test = []
files = data_dir_test.glob('*.jpg')
for myFile in files:
    print(myFile)
    image = cv2.imread(str(myFile), cv2.IMREAD_COLOR)
    X_data_test.append(image/255)
X_data_test = np.array(X_data_test)
print('X_data_test shape:', X_data_test.shape)

# %%
def one_hot_encode(classes, num_in_class, index):
    arr = np.zeros((num_in_class, classes))
    arr[:, index] = 1
    return arr

# %%
y_data = np.zeros((87000, 29))
for i in range(29):
    labels = one_hot_encode(29, 3000, i)
    y_data[i*3000:i*3000+3000,:] = labels
y_data.shape

# %%
y_data_test = np.zeros((29, 29))
for i in range(29):
    labels = one_hot_encode(29, 1, i)
    y_data_test[i,:] = labels
y_data_test.shape

# %%
y_data.shape
# Out:
# (87000, 29)

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"])
CLASS_NAMES
# Out:
# array(['A', 'B', 'C', 'D', 'del', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L',
#        'M', 'N', 'nothing', 'O', 'P', 'Q', 'R', 'S', 'space', 'T', 'U',
#        'V', 'W', 'X', 'Y', 'Z'], dtype='<U7')

# %%
a_images = list(data_dir.glob(str(CLASS_NAMES[0])+'/*'))
for image_path in a_images[:3]:
    display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x1C2FA09F9E8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x1C2FA09FA20>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x1C2FA8F4DA0>

# %%
BATCH_SIZE = 64
IMG_HEIGHT = 200
IMG_WIDTH = 200

# %% [markdown]
# Run the next cell to load the "SIGNS" dataset you are going to use.

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*'))
print(list_ds)
for f in list_ds.take(10):
    print(f)
# Out:
# <DatasetV1Adapter shapes: (), types: tf.string>
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\Z\\Z1007.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\Z\\Z1267.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\O\\O1206.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\P\\P1918.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\T\\T2098.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\P\\P1502.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\U\\U1615.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\T\\T1302.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\space\\space2558.jpg', shape=(), dtype=string)
# tf.Tensor(b'data\\asl_alphabet_train\\asl_alphabet_train\\R\\R1624.jpg', shape=(), dtype=string)

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, '/')
    return parts[-2] == CLASS_NAMES

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) #color images
    img = tf.image.convert_image_dtype(img, tf.float32) 
   #convert unit8 tensor to floats in the [0,1]range
    return tf.image.resize(img, [IMG_WIDTH, IMG_HEIGHT]) 
#resize the image into 224*224

# %%
def process_path(file_path):
    print(file_path)
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    print("Image shape: ", img)
    print("Label: ", label)
    return img, label

# %%
labeled_ds = list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
# Out:
# Tensor("args_0:0", shape=(), dtype=string)
# Image shape:  Tensor("resize/Squeeze:0", shape=(200, 200, 3), dtype=float32)
# Label:  Tensor("Equal:0", shape=(29,), dtype=bool)

# %%
for image, label in labeled_ds:
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-32-e3d9627671ac> in <module>
# ----> 1 for image, label in labeled_ds:
#       2     print("Image shape: ", image.numpy().shape)
#       3     print("Label: ", label.numpy())
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in __next__(self)
#     620
#     621   def __next__(self):  # For Python 3 compatibility
# --> 622     return self.next()
#     623
#     624   def _next_internal(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in next(self)
#     664     """Returns a nested structure of `Tensor`s containing the next element."""
#     665     try:
# --> 666       return self._next_internal()
#     667     except errors.OutOfRangeError:
#     668       raise StopIteration
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in _next_internal(self)
#     649             self._iterator_resource,
#     650             output_types=self._flat_output_types,
# --> 651             output_shapes=self._flat_output_shapes)
#     652
#     653       try:
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\ops\gen_dataset_ops.py in iterator_get_next_sync(iterator, output_types, output_shapes, name)
#    2671       else:
#    2672         message = e.message
# -> 2673       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    2674   # Add nodes to the TensorFlow graph.
#    2675   if not isinstance(output_types, (list, tuple)):
#
# c:\users\tobyw\anaconda3\envs\tensorflow_gpu\lib\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError: {{function_node __inference_Dataset_map_process_path_214}} slice index -1 of dimension 0 out of bounds.
# 	 [[{{node strided_slice}}]] [Op:IteratorGetNextSync]

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat() #repeat forever
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

# %%
tf.executing_eagerly()
# Out:
# True

# %%
train_ds = prepare_for_training(labeled_ds)
image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-25-2ca3747fb8e9> in <module>
#       1 train_ds = prepare_for_training(labeled_ds)
# ----> 2 image_batch, label_batch = next(iter(train_ds))
#       3 show_batch(image_batch.numpy(), label_batch.numpy())
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in __next__(self)
#     620
#     621   def __next__(self):  # For Python 3 compatibility
# --> 622     return self.next()
#     623
#     624   def _next_internal(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in next(self)
#     664     """Returns a nested structure of `Tensor`s containing the next element."""
#     665     try:
# --> 666       return self._next_internal()
#     667     except errors.OutOfRangeError:
#     668       raise StopIteration
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in _next_internal(self)
#     649             self._iterator_resource,
#     650             output_types=self._flat_output_types,
# --> 651             output_shapes=self._flat_output_shapes)
#     652
#     653       try:
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\ops\gen_dataset_ops.py in iterator_get_next_sync(iterator, output_types, output_shapes, name)
#    2671       else:
#    2672         message = e.message
# -> 2673       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    2674   # Add nodes to the TensorFlow graph.
#    2675   if not isinstance(output_types, (list, tuple)):
#
# c:\users\tobyw\anaconda3\envs\tensorflow_gpu\lib\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError: {{function_node __inference_Dataset_map_process_path_214}} slice index -1 of dimension 0 out of bounds.
# 	 [[{{node strided_slice}}]] [Op:IteratorGetNextSync]

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %% [markdown]
# As a reminder, the SIGNS dataset is a collection of 6 signs representing numbers from 0 to 5.
#
# <img src="images/SIGNS.png" style="width:800px;height:300px;">
#
# The next cell will show you an example of a labelled image in the dataset. Feel free to change the value of `index` below and re-run to see different examples.

# %%
# Example of a picture
index = 6
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 2

# %% [markdown]
# In Course 2, you had built a fully-connected network for this dataset. But since this is an image dataset, it is more natural to apply a ConvNet to it.
#
# To get started, let's examine the shapes of your data.

# %%
X_data = X_data/255.
X_data_test = X_data_test/255.
# Y_train = convert_to_one_hot(Y_train_orig, 6).T
# Y_test = convert_to_one_hot(Y_test_orig, 6).T
# Y_train = y_data
# Y_test = y_data_test
# print ("number of training examples = " + str(X_train.shape[0]))
# print ("number of test examples = " + str(X_test.shape[0]))
# print ("X_train shape: " + str(X_train.shape))
# print ("Y_train shape: " + str(Y_train.shape))
# print ("X_test shape: " + str(X_test.shape))
# print ("Y_test shape: " + str(Y_test.shape))
# conv_layers = {}
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-fe1a39e44902> in <module>
# ----> 1 X_data = X_data/255.
#       2 X_data_test = X_data_test/255.
#       3 # Y_train = convert_to_one_hot(Y_train_orig, 6).T
#       4 # Y_test = convert_to_one_hot(Y_test_orig, 6).T
#       5 # Y_train = y_data
#
# MemoryError: Unable to allocate array with shape (87000, 200, 200, 3) and data type float64

# %% [markdown]
# ### 1.1 - Create placeholders
#
# TensorFlow requires that you create placeholders for the input data that will be fed into the model when running the session.
#
# **Exercise**: Implement the function below to create placeholders for the input image X and the output Y. You should not define the number of training examples for the moment. To do so, you could use "None" as the batch size, it will give you the flexibility to choose it later. Hence X should be of dimension **[None, n_H0, n_W0, n_C0]** and Y should be of dimension **[None, n_y]**.  [Hint: search for the tf.placeholder documentation"](https://www.tensorflow.org/api_docs/python/tf/placeholder).

# %%
# GRADED FUNCTION: create_placeholders

def create_placeholders(n_H0, n_W0, n_C0, n_y):
    """
    Creates the placeholders for the tensorflow session.
    
    Arguments:
    n_H0 -- scalar, height of an input image
    n_W0 -- scalar, width of an input image
    n_C0 -- scalar, number of channels of the input
    n_y -- scalar, number of classes
        
    Returns:
    X -- placeholder for the data input, of shape [None, n_H0, n_W0, n_C0] and dtype "float"
    Y -- placeholder for the input labels, of shape [None, n_y] and dtype "float"
    """

    X = tf.compat.v1.placeholder(tf.float32, shape=[None, n_H0, n_W0, n_C0])
    # pad input for now to get size 227x227 for AlexNet recommendations
    Y = tf.compat.v1.placeholder(tf.float32, shape=[None, n_y])
    
    return X, Y

# %%
X, Y = create_placeholders(64, 64, 3, 6)
print ("X = " + str(X))
print ("Y = " + str(Y))
# Out:
# X = Tensor("Placeholder_2:0", shape=(?, 64, 64, 3), dtype=float32)
# Y = Tensor("Placeholder_3:0", shape=(?, 6), dtype=float32)

# %% [markdown]
# **Expected Output**
#
# <table>
# <tr>
# <td>
#     X = Tensor("Placeholder:0", shape=(?, 64, 64, 3), dtype=float32)
#
# </td>
# </tr>
# <tr>
# <td>
#     Y = Tensor("Placeholder_1:0", shape=(?, 6), dtype=float32)
#
# </td>
# </tr>
# </table>

# %% [markdown]
# ### 1.2 - Initialize parameters
#
# You will initialize weights/filters $W1$ and $W2$ using `tf.contrib.layers.xavier_initializer(seed = 0)`. You don't need to worry about bias variables as you will soon see that TensorFlow functions take care of the bias. Note also that you will only initialize the weights/filters for the conv2d functions. TensorFlow initializes the layers for the fully connected part automatically. We will talk more about that later in this assignment.
#
# **Exercise:** Implement initialize_parameters(). The dimensions for each group of filters are provided below. Reminder - to initialize a parameter $W$ of shape [1,2,3,4] in Tensorflow, use:
# ```python
# W = tf.get_variable("W", [1,2,3,4], initializer = ...)
# ```
# #### tf.get_variable()
# [Search for the tf.get_variable documentation](https://www.tensorflow.org/api_docs/python/tf/get_variable).  Notice that the documentation says:
# ```
# Gets an existing variable with these parameters or create a new one.
# ```
# So we can use this function to create a tensorflow variable with the specified name, but if the variables already exist, it will get the existing variable with that same name.

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters():
    """
    Initializes weight parameters to build a neural network with tensorflow. The shapes are:
                        W1 : [4, 4, 3, 8]
                        W2 : [2, 2, 8, 16]
    Note that we will hard code the shape values in the function to make the grading simpler.
    Normally, functions should take values as inputs rather than hard coding.
    Returns:
    parameters -- a dictionary of tensors containing W1, W2
    """
    
    # tf.set_random_seed(1)                              # so that your "random" numbers match ours
        
    ### START CODE HERE ### (approx. 2 lines of code)
    initializer = tf.initializers.GlorotUniform()

    #initializer = tf.compat.v1.contrib.layers.xavier_initializer(seed=0)
    W1 = tf.compat.v1.get_variable('W1', [11,11,3,96], initializer=initializer)
    W2 = tf.compat.v1.get_variable('W2', [5,5,96,256], initializer=initializer)
    W3 = tf.compat.v1.get_variable('W3', [3,3,256,384], initializer=initializer)
    W4 = tf.compat.v1.get_variable('W4', [3,3,384,384], initializer=initializer)
    W5 = tf.compat.v1.get_variable('W5', [3,3,384,256], initializer=initializer)
    ### END CODE HERE ###

    parameters = {"W1": W1,
                  "W2": W2,
                  "W3": W3,
                  "W4": W4,
                  "W5": W5}
    
    return parameters

# %%
tf.compat.v1.reset_default_graph()
with tf.compat.v1.Session() as sess_test:
    parameters = initialize_parameters()
    init = tf.compat.v1.global_variables_initializer()
    sess_test.run(init)
    print("W1[1,1,1] = \n" + str(parameters["W1"].eval()[1,1,1]))
    print("W1.shape: " + str(parameters["W1"].shape))
    print("\n")
    print("W2[1,1,1] = \n" + str(parameters["W2"].eval()[1,1,1]))
    print("W2.shape: " + str(parameters["W2"].shape))
# Out:
# W1[1,1,1] =
# [ 0.00244587  0.01414685 -0.00858323 -0.0154583  -0.01658734  0.01706694
#  -0.01482233  0.01589944  0.00511404  0.00414253 -0.00090732  0.0071043
#   0.00011919  0.01595276 -0.01403172 -0.0107449  -0.00058719  0.01609599
#   0.02028423  0.01916039  0.00047421  0.00578076 -0.0088071   0.01879757
#  -0.01531659 -0.00236917 -0.02052385  0.01581304  0.00661279 -0.01523155
#  -0.0096839  -0.01930999  0.00472574 -0.00234516 -0.00490643 -0.00104656
#   0.00814992 -0.00598614  0.01930928  0.00293962 -0.00204224  0.0009492
#  -0.0032433   0.0186563  -0.00695989 -0.00255804  0.00439746 -0.01186998
#  -0.01623058  0.00177409  0.01343361 -0.01696283  0.00961194  0.00485125
#   0.00787567 -0.01833746 -0.01805935 -0.00992464  0.01082124 -0.01213678
#  -0.02411477 -0.02002549 -0.0013587   0.02012626  0.02218702 -0.02478971
#  -0.00214764 -0.0077517   0.000247   -0.02354359  0.02393391  0.02211531
#   0.01939031 -0.02290152  0.01112314  0.01615528 -0.02354335 -0.01609228
#  -0.00711801  0.0116543  -0.0137007   0.00709741 -0.00384014 -0.0099821
#   0.02042656  0.00970906 -0.02226874 -0.02521731  0.00877518  0.02511903
#  -0.00371355  0.00923142 -0.00165748  0.01819574 -0.00951653  0.00328974
#  -0.00733796 -0.02157423  0.00752027 -0.02455997  0.02526963  0.01666788
#  -0.00688648  0.02194652 -0.01706751  0.02401194 -0.01487554 -0.02412598
#  -0.02240153 -0.02458208  0.01793761 -0.01844815 -0.01187561 -0.01165942
#   0.01540937 -0.00011313 -0.014627   -0.00692498  0.01226601  0.01692163
#  -0.02178069  0.02038516 -0.00179837 -0.00987175]
# W2.shape: (5, 5, 96, 256)

# %% [markdown]
# ** Expected Output:**
#
# ```
# W1[1,1,1] =
# [ 0.00131723  0.14176141 -0.04434952  0.09197326  0.14984085 -0.03514394
#  -0.06847463  0.05245192]
# W1.shape: (4, 4, 3, 8)
#
#
# W2[1,1,1] =
# [-0.08566415  0.17750949  0.11974221  0.16773748 -0.0830943  -0.08058
#  -0.00577033 -0.14643836  0.24162132 -0.05857408 -0.19055021  0.1345228
#  -0.22779644 -0.1601823  -0.16117483 -0.10286498]
# W2.shape: (2, 2, 8, 16)
# ```

# %% [markdown]
# ### 1.3 - Forward propagation
#
# In TensorFlow, there are built-in functions that implement the convolution steps for you.
#
# - **tf.nn.conv2d(X,W, strides = [1,s,s,1], padding = 'SAME'):** given an input $X$ and a group of filters $W$, this function convolves $W$'s filters on X. The third parameter ([1,s,s,1]) represents the strides for each dimension of the input (m, n_H_prev, n_W_prev, n_C_prev). Normally, you'll choose a stride of 1 for the number of examples (the first value) and for the channels (the fourth value), which is why we wrote the value as `[1,s,s,1]`. You can read the full documentation on [conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# - **tf.nn.max_pool(A, ksize = [1,f,f,1], strides = [1,s,s,1], padding = 'SAME'):** given an input A, this function uses a window of size (f, f) and strides of size (s, s) to carry out max pooling over each window.  For max pooling, we usually operate on a single example at a time and a single channel at a time.  So the first and fourth value in `[1,f,f,1]` are both 1.  You can read the full documentation on [max_pool](https://www.tensorflow.org/api_docs/python/tf/nn/max_pool).
#
# - **tf.nn.relu(Z):** computes the elementwise ReLU of Z (which can be any shape). You can read the full documentation on [relu](https://www.tensorflow.org/api_docs/python/tf/nn/relu).
#
# - **tf.contrib.layers.flatten(P)**: given a tensor "P", this function takes each training (or test) example in the batch and flattens it into a 1D vector.
#     * If a tensor P has the shape (m,h,w,c), where m is the number of examples (the batch size), it returns a flattened tensor with shape (batch_size, k), where $k=h \times w \times c$.  "k" equals the product of all the dimension sizes other than the first dimension.
#     * For example, given a tensor with dimensions [100,2,3,4], it flattens the tensor to be of shape [100, 24], where 24 = 2 * 3 * 4.  You can read the full documentation on [flatten](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/flatten).
#
# - **tf.contrib.layers.fully_connected(F, num_outputs):** given the flattened input F, it returns the output computed using a fully connected layer. You can read the full documentation on [full_connected](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/fully_connected).
#
# In the last function above (`tf.contrib.layers.fully_connected`), the fully connected layer automatically initializes weights in the graph and keeps on training them as you train the model. Hence, you did not need to initialize those weights when initializing the parameters.
#
#
# #### Window, kernel, filter
# The words "window", "kernel", and "filter" are used to refer to the same thing.  This is why the parameter `ksize` refers to "kernel size", and we use `(f,f)` to refer to the filter size.  Both "kernel" and "filter" refer to the "window."

# %% [markdown]
# **Exercise**
#
# Implement the `forward_propagation` function below to build the following model: `CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> FULLYCONNECTED`. You should use the functions above.
#
# In detail, we will use the following parameters for all the steps:
#  - Conv2D: stride 1, padding is "SAME"
#  - ReLU
#  - Max pool: Use an 8 by 8 filter size and an 8 by 8 stride, padding is "SAME"
#  - Conv2D: stride 1, padding is "SAME"
#  - ReLU
#  - Max pool: Use a 4 by 4 filter size and a 4 by 4 stride, padding is "SAME"
#  - Flatten the previous output.
#  - FULLYCONNECTED (FC) layer: Apply a fully connected layer without an non-linear activation function. Do not call the softmax here. This will result in 6 neurons in the output layer, which then get passed later to a softmax. In TensorFlow, the softmax and cost function are lumped together into a single function, which you'll call in a different function when computing the cost.

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> FULLYCONNECTED
    
    Note that for simplicity and grading purposes, we'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    X -- input dataset placeholder, of shape (input size, number of examples)
    parameters -- python dictionary containing your parameters "W1", "W2"
                  the shapes are given in initialize_parameters

    Returns:
    Z3 -- the output of the last LINEAR unit
    """
    
    # Retrieve the parameters from the dictionary "parameters" 
    W1 = parameters['W1']
    W2 = parameters['W2']
    W3 = parameters['W3']
    W4 = parameters['W4']
    W5 = parameters['W5']
    
    ### START CODE HERE ###
    # CONV2D: stride of 4, no padding
    Z1 = tf.nn.conv2d(X, W1, strides=[1,4,4,1], padding='SAME')
    # RELU
    A1 = tf.nn.relu(Z1)
    # MAXPOOL: window 3x3, stride 2, padding 'VALID'
    P1 = tf.nn.max_pool(A1, ksize=[1,3,3,1], strides=[1,2,2,1], padding='VALID')
    # CONV2D: filters W2, stride 1, padding = 2 
    P1 = tf.pad(P1, [[0,0], [2,2], [2,2], [0,0]])
    Z2 = tf.nn.conv2d(P1, W2, strides=[1,1,1,1], padding='VALID')
    # RELU
    A2 = tf.nn.relu(Z2)
    # MAXPOOL: window 4x4, stride 4
    P2 = tf.nn.max_pool(A2, ksize=[1,3,3,1], strides=[1,2,2,1], padding='VALID')
    # CONV2D
    P2 = tf.pad(P2, [[0,0], [1,1], [1,1], [0,0]])
    Z3 = tf.nn.conv2d(P2, W3, strides=[1,1,1,1], padding='VALID')
    #RELU
    A3 = tf.nn.relu(Z3)
    #CONV2D
    A3 = tf.pad(A3, [[0,0], [1,1], [1,1], [0,0]])
    Z4 = tf.nn.conv2d(A3, W4, strides=[1,1,1,1], padding='VALID')
    #RELU
    A4 = tf.nn.relu(Z4)
    #CONV2D
    A4 = tf.pad(A4, [[0,0], [1,1], [1,1], [0,0]])
    Z5 = tf.nn.conv2d(A4, W5, strides=[1,1,1,1], padding='VALID')
    #RELU
    A5 = tf.nn.relu(Z5)
    #max POOL
    P5 = tf.nn.max_pool(A5, ksize=[1,3,3,1], strides=[1,2,2,1], padding='VALID')
    # FLATTEN
    F = tf.compat.v1.layers.flatten(P5)
    # FULLY-CONNECTED without non-linear activation function (not not call softmax).
    # 6 neurons in output layer. Hint: one of the arguments should be "activation_fn=None" 
    Z6 = tf.keras.layers.Dense(4096, activation='relu')(F)
    Z7 = tf.keras.layers.Dense(4096, activation='relu')(Z6)
    Z8 = tf.keras.layers.Dense(6, activation=None)(Z7)
    ### END CODE HERE ###

    return Z8

# %%
tf.compat.v1.reset_default_graph()

with tf.compat.v1.Session() as sess:
    np.random.seed(1)
    X, Y = create_placeholders(64, 64, 3, 6)
    parameters = initialize_parameters()
    Z8 = forward_propagation(X, parameters)
    init = tf.compat.v1.global_variables_initializer()
    sess.run(init)
    a = sess.run(Z8, {X: np.random.randn(2,64,64,3), Y: np.random.randn(2,6)})
    print("Z8 = \n" + str(a))
# Out:
# Z8 =
# [[ 0.00120531  0.00448333  0.00535069 -0.03590677  0.00048453  0.03381554]
#  [ 0.00040389 -0.00123707  0.00493524 -0.02833511  0.00203724  0.0320693 ]]

# %% [markdown]
# **Expected Output**:
#
# ```
# Z3 =
# [[-0.44670227 -1.57208765 -1.53049231 -2.31013036 -1.29104376  0.46852064]
#  [-0.17601591 -1.57972014 -1.4737016  -2.61672091 -1.00810647  0.5747785 ]]
# ```

# %% [markdown]
# ### 1.4 - Compute cost
#
# Implement the compute cost function below. Remember that the cost function helps the neural network see how much the model's predictions differ from the correct labels.  By adjusting the weights of the network to reduce the cost, the neural network can improve its predictions.
#
# You might find these two functions helpful:
#
# - **tf.nn.softmax_cross_entropy_with_logits(logits = Z, labels = Y):** computes the softmax entropy loss. This function both computes the softmax activation function as well as the resulting loss. You can check the full documentation  [softmax_cross_entropy_with_logits](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits).
# - **tf.reduce_mean:** computes the mean of elements across dimensions of a tensor. Use this to calculate the sum of the losses over all the examples to get the overall cost. You can check the full documentation [reduce_mean](https://www.tensorflow.org/api_docs/python/tf/reduce_mean).
#
# #### Details on softmax_cross_entropy_with_logits (optional reading)
# * Softmax is used to format outputs so that they can be used for classification.  It assigns a value between 0 and 1 for each category, where the sum of all prediction values (across all possible categories) equals 1.
# * Cross Entropy is compares the model's predicted classifications with the actual labels and results in a numerical value representing the "loss" of the model's predictions.
# * "Logits" are the result of multiplying the weights and adding the biases.  Logits are passed through an activation function (such as a relu), and the result is called the "activation."
# * The function is named `softmax_cross_entropy_with_logits` takes logits as input (and not activations); then uses the model to predict using softmax, and then compares the predictions with the true labels using cross entropy.  These are done with a single function to optimize the calculations.
#
# ** Exercise**: Compute the cost below using the function above.

# %%
# GRADED FUNCTION: compute_cost 

def compute_cost(Z8, Y):
    """
    Computes the cost
    
    Arguments:
    Z3 -- output of forward propagation (output of the last LINEAR unit), of shape (number of examples, 6)
    Y -- "true" labels vector placeholder, same shape as Z3
    
    Returns:
    cost - Tensor of the cost function
    """
    
    ### START CODE HERE ### (1 line of code)
    cost = tf.nn.softmax_cross_entropy_with_logits(logits=Z8, labels=Y)
    cost = tf.reduce_mean(cost)
    ### END CODE HERE ###
    
    return cost

# %%
tf.compat.v1.reset_default_graph()

with tf.compat.v1.Session() as sess:
    np.random.seed(1)
    X, Y = create_placeholders(227, 227, 3, 6)
    parameters = initialize_parameters()
    Z8 = forward_propagation(X, parameters)
    cost = compute_cost(Z8, Y)
    init = tf.compat.v1.global_variables_initializer()
    sess.run(init)
    a = sess.run(cost, {X: np.random.randn(4,227,227,3), Y: np.random.randn(4,6)})
    print("cost = " + str(a))
# Out:
# cost = -0.13656664

# %% [markdown]
# **Expected Output**:
# ```
# cost = 2.91034
# ```

# %% [markdown]
# ## 1.5 Model
#
# Finally you will merge the helper functions you implemented above to build a model. You will train it on the SIGNS dataset.
#
# **Exercise**: Complete the function below.
#
# The model below should:
#
# - create placeholders
# - initialize parameters
# - forward propagate
# - compute the cost
# - create an optimizer
#
# Finally you will create a session and run a for loop  for num_epochs, get the mini-batches, and then for each mini-batch you will optimize the function. [Hint for initializing the variables](https://www.tensorflow.org/api_docs/python/tf/global_variables_initializer)

# %% [markdown]
# #### Adam Optimizer
# You can use `tf.train.AdamOptimizer(learning_rate = ...)` to create the optimizer.  The optimizer has a `minimize(loss=...)` function that you'll call to set the cost function that the optimizer will minimize.
#
# For details, check out the documentation for [Adam Optimizer](https://www.tensorflow.org/api_docs/python/tf/train/AdamOptimizer)

# %% [markdown]
# #### Random mini batches
# If you took course 2 of the deep learning specialization, you implemented `random_mini_batches()` in the "Optimization" programming assignment. This function returns a list of mini-batches. It is already implemented in the `cnn_utils.py` file and imported here, so you can call it like this:
# ```Python
# minibatches = random_mini_batches(X, Y, mini_batch_size = 64, seed = 0)
# ```
# (You will want to choose the correct variable names when you use it in your code).

# %% [markdown]
# #### Evaluating the optimizer and cost
#
# Within a loop, for each mini-batch, you'll use the `tf.Session` object (named `sess`) to feed a mini-batch of inputs and labels into the neural network and evaluate the tensors for the optimizer as well as the cost.  Remember that we built a graph data structure and need to feed it inputs and labels and use `sess.run()` in order to get values for the optimizer and cost.
#
# You'll use this kind of syntax:
# ```
# output_for_var1, output_for_var2 = sess.run(
#                                                 fetches=[var1, var2],
#                                                 feed_dict={var_inputs: the_batch_of_inputs,
#                                                            var_labels: the_batch_of_labels}
#                                                 )
# ```
# * Notice that `sess.run` takes its first argument `fetches` as a list of objects that you want it to evaluate (in this case, we want to evaluate the optimizer and the cost).
# * It also takes a dictionary for the `feed_dict` parameter.
# * The keys are the `tf.placeholder` variables that we created in the `create_placeholders` function above.
# * The values are the variables holding the actual numpy arrays for each mini-batch.
# * The sess.run outputs a tuple of the evaluated tensors, in the same order as the list given to `fetches`.
#
# For more information on how to use sess.run, see the documentation [tf.Sesssion#run](https://www.tensorflow.org/api_docs/python/tf/Session#run) documentation.

# %%
# GRADED FUNCTION: model

def model(X_train, Y_train, X_test, Y_test, learning_rate = 0.001,
          num_epochs = 100, minibatch_size = 64, print_cost = True):
    """
    Implements a three-layer ConvNet in Tensorflow:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> FULLYCONNECTED
    
    Arguments:
    X_train -- training set, of shape (None, 64, 64, 3)
    Y_train -- test set, of shape (None, n_y = 6)
    X_test -- training set, of shape (None, 64, 64, 3)
    Y_test -- test set, of shape (None, n_y = 6)
    learning_rate -- learning rate of the optimization
    num_epochs -- number of epochs of the optimization loop
    minibatch_size -- size of a minibatch
    print_cost -- True to print the cost every 100 epochs
    
    Returns:
    train_accuracy -- real number, accuracy on the train set (X_train)
    test_accuracy -- real number, testing accuracy on the test set (X_test)
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    ops.reset_default_graph()                         # to be able to rerun the model without overwriting tf variables
    # tf.set_random_seed(1)                             # to keep results consistent (tensorflow seed)
    seed = 3                                          # to keep results consistent (numpy seed)
    (m, n_H0, n_W0, n_C0) = X_train.shape    
#     n_H0 = 227 #hardcode AlexNet dimensions of 227x227 to avoid negative dimensions
#     n_W0 = 227
    n_y = Y_train.shape[1]                            
    costs = []                                        # To keep track of the cost
    
    # Create Placeholders of the correct shape
    ### START CODE HERE ### (1 line)
    # pad X  to size 227x227
    print('original X_train size:', X_train.shape)
#     X_train = np.pad(X_train, ((0,0), (81,82), (81,82), (0,0)), mode='constant', constant_values=[(0,0), (0,0), (0,0), (0,0)])
#     print('new X_train size:', X_train.shape)
    print('original X_test size:', X_test.shape)
#     X_test = np.pad(X_test, ((0,0), (81,82), (81,82), (0,0)), mode='constant', constant_values=[(0,0), (0,0), (0,0), (0,0)])
#     print('new X_test size:', X_test.shape)
    X, Y = create_placeholders(n_H0, n_W0, n_C0, n_y)
    ### END CODE HERE ###

    # Initialize parameters
    ### START CODE HERE ### (1 line)
    parameters = initialize_parameters()
    ### END CODE HERE ###
    
    # Forward propagation: Build the forward propagation in the tensorflow graph
    ### START CODE HERE ### (1 line)
    Z8 = forward_propagation(X, parameters)
    ### END CODE HERE ###
    
    # Cost function: Add cost function to tensorflow graph
    ### START CODE HERE ### (1 line)
    cost = compute_cost(Z8, Y)
    ### END CODE HERE ###
    
    # Backpropagation: Define the tensorflow optimizer. Use an AdamOptimizer that minimizes the cost.
    ### START CODE HERE ### (1 line)
    optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss=cost)
    ### END CODE HERE ###
    
    # Initialize all the variables globally
    init = tf.compat.v1.global_variables_initializer()
    

    # Start the session to compute the tensorflow graph
    with tf.compat.v1.Session() as sess:
        
        # Run the initialization
        sess.run(init)
        
        # Do the training loop
        for epoch in range(num_epochs):

            minibatch_cost = 0.
            num_minibatches = int(m / minibatch_size) # number of minibatches of size minibatch_size in the train set
            seed = seed + 1
            minibatches = random_mini_batches(X_train, Y_train, minibatch_size, seed)

            for minibatch in minibatches:

                # Select a minibatch
                (minibatch_X, minibatch_Y) = minibatch
                
                """
                # IMPORTANT: The line that runs the graph on a minibatch.
                # Run the session to execute the optimizer and the cost.
                # The feedict should contain a minibatch for (X,Y).
                """
                ### START CODE HERE ### (1 line)
                _ , temp_cost = sess.run([optimizer, cost], feed_dict={X:minibatch_X, Y:minibatch_Y})
                ### END CODE HERE ###
                
                minibatch_cost += temp_cost / num_minibatches
                print ("temp cost for epoch %i: %f" % (epoch, temp_cost))

            # Print the cost every epoch
            if print_cost == True and epoch % 5 == 0:
                print ("Cost after epoch %i: %f" % (epoch, minibatch_cost))
            if print_cost == True and epoch % 1 == 0:
                costs.append(minibatch_cost)
        
        
        # plot the cost
        plt.plot(np.squeeze(costs))
        plt.ylabel('cost')
        plt.xlabel('iterations (per tens)')
        plt.title("Learning rate =" + str(learning_rate))
        plt.show()

        # Calculate the correct predictions
        predict_op = tf.argmax(Z8, 1)
        correct_prediction = tf.equal(predict_op, tf.argmax(Y, 1))
        
        # Calculate accuracy on the test set
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
        print(accuracy)
        train_accuracy = accuracy.eval({X: X_train, Y: Y_train})
        test_accuracy = accuracy.eval({X: X_test, Y: Y_test})
        print("Train Accuracy:", train_accuracy)
        print("Test Accuracy:", test_accuracy)
                
        return train_accuracy, test_accuracy, parameters

# %% [markdown]
# Run the following cell to train your model for 100 epochs. Check if your cost after epoch 0 and 5 matches our output. If not, stop the cell and go back to your code!

# %%
_, _, parameters = model(X_data, y_data, X_data_test, y_data_test)

# %% [markdown]
# **Expected output**: although it may not match perfectly, your expected output should be close to ours and your cost value should decrease.
#
# <table>
# <tr>
#     <td>
#     **Cost after epoch 0 =**
#     </td>
#
#     <td>
#       1.917929
#     </td>
# </tr>
# <tr>
#     <td>
#     **Cost after epoch 5 =**
#     </td>
#
#     <td>
#       1.506757
#     </td>
# </tr>
# <tr>
#     <td>
#     **Train Accuracy   =**
#     </td>
#
#     <td>
#       0.940741
#     </td>
# </tr>
#
# <tr>
#     <td>
#     **Test Accuracy   =**
#     </td>
#
#     <td>
#       0.783333
#     </td>
# </tr>
# </table>

# %% [markdown]
# Congratulations! You have finished the assignment and built a model that recognizes SIGN language with almost 80% accuracy on the test set. If you wish, feel free to play around with this dataset further. You can actually improve its accuracy by spending more time tuning the hyperparameters, or using regularization (as this model clearly has a high variance).
#
# Once again, here's a thumbs up for your work!

# %%
fname = "images/thumbs_up.jpg"
image = np.array(ndimage.imread(fname, flatten=False))
my_image = scipy.misc.imresize(image, size=(64,64))
plt.imshow(my_image)
